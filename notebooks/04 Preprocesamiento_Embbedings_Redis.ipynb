# %% [markdown]
# # 4. Preparar Documentos
# En este notebook se desarrolla el preprocesamiento necesario para la generación de embeddings a partir de los textos normativos, con el objetivo de indexar la información en una base Redis para su posterior consulta semántica y recuperación eficiente. El proceso abarca la preparación de los textos, el uso de modelos de lenguaje para obtener representaciones vectoriales (embeddings) y la estructuración de la información para su integración en el pipeline de gestión normativa.

# %%
# library
import pandas as pd
from typing import List, Union
import tiktoken
import redis as RedisClient

from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores.redis.base import Redis as RedisVectorStore

from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_core.documents import Document
from collections import Counter


import numpy as np
from redis.commands.search.query import Query
from IPython.display import display, HTML

# %%
# -------------------------------
# CONSTANTS
# -------------------------------
REDIS_HOST = "localhost"
REDIS_PORT = 6379
REDIS_DB = 0
REDIS_USERNAME = "default"
REDIS_PASSWORD = ""
REDIS_INDEX = "normativas_sii"
GPT_KEY = "sk-proj--....."  # ← Reemplázalo por tu clave real
REDIS_URL = f"redis://{REDIS_USERNAME}:{REDIS_PASSWORD}@{REDIS_HOST}:{REDIS_PORT}/{REDIS_DB}"
DATA_DIR ="../raw_data"
CSV_PATH = "classified_regulations.csv"
MODEL_NAME = "text-embedding-3-large"  # Modelo de OpenAI para embeddings
# Tokenizador para OpenAI embeddings
tokenizer = tiktoken.encoding_for_model(MODEL_NAME)
MAX_TOKENS = 30000
SAFE_TOKENS = 25000  # margen de seguridad

# %% [markdown]
# ## 4.1 Carga de Datos
# En esta sección se realiza la carga de los datos normativos previamente preprocesados. Los datos contienen los textos completos y la metadata relevante asociada a cada normativa. Esta información será utilizada como insumo para la generación de los embeddings.
#
# Se aplica un preprocesamiento básico a los textos normativos para optimizar la calidad de los embeddings generados. Esto puede incluir normalización de caracteres, eliminación de símbolos innecesarios y, en algunos casos, reducción de ruido textual. El objetivo es asegurar que la representación vectorial capture el contenido semántico relevante de cada normativa.
#
# Utilizando un modelo de lenguaje preentrenado, se obtienen los embeddings para cada texto normativo. Estos vectores numéricos permiten comparar y recuperar información normativa de manera eficiente, habilitando funcionalidades avanzadas de búsqueda y clasificación semántica.

# %%
# -------------------------------
# FUNCTIONS
# -------------------------------
def contar_tokens(texto: str) -> int:
    """
    Counts the number of tokens in a given text using the default tokenizer.

    Parameters:
    - texto (str): The input text to tokenize and count.

    Returns:
    - int: The number of tokens in the provided text.
    """
    return len(tokenizer.encode(texto))


def resumen_chunks_por_documento(documentos):
    """
    Imprime un resumen del número de chunks generados por cada documento.

    Para cada documento en la lista, cuenta cuántos chunks (fragmentos) le corresponden
    y muestra el total de chunks junto a un resumen por documento.

    Parámetros:
    - documentos (list): Lista de objetos documento, cada uno debe tener un atributo 'metadata' 
      con al menos la clave 'name'.

    Retorna:
    - None. Solo imprime el resumen en consola.
    """
    conteo = Counter(doc.metadata.get("name", "Sin nombre") for doc in documentos)
    print(f"Total de chunks generados: {len(documentos)}")
    print("Resumen por documento:")
    for nombre, cantidad in conteo.items():
        print(f"- {nombre}: {cantidad} chunk(s)")



def preparar_documentos(path_csv: str,
                        n: int = None,
                        anios: Union[int, List[int]] = None,
                        chunk_size: int = None,
                        chunk_overlap: int = None) -> List[Document]:
    """
    Carga y prepara documentos desde un archivo CSV para procesamiento de NLP o indexación.

    - Lee el archivo CSV y filtra filas con valor nulo en la columna "corpus".
    - Permite filtrar documentos por uno o varios años especificados en 'anios'.
    - Puede limitar la cantidad de documentos a los primeros 'n' del DataFrame.
    - Si se indican 'chunk_size' y 'chunk_overlap', fragmenta los textos largos en chunks seguros.
    - Solo incluye documentos o fragmentos que no superen el límite seguro de tokens.
    - Los metadatos relevantes se asocian a cada documento.

    Parámetros:
    - path_csv (str): Ruta al archivo CSV de entrada.
    - n (int, opcional): Número máximo de documentos a procesar (None = todos).
    - anios (int o List[int], opcional): Año(s) a filtrar en la columna 'nombre'.
    - chunk_size (int, opcional): Tamaño máximo de chunk (en tokens) para fragmentar los textos largos.
    - chunk_overlap (int, opcional): Cantidad de tokens de solapamiento entre chunks.

    Retorna:
    - List[Document]: Lista de objetos Document listos para procesamiento o indexación.

    Notas:
    - Usa la variable SAFE_TOKENS para controlar el límite máximo de tokens por documento o chunk.
    - Si un documento supera el límite y no se especifica chunking, se omite y se imprime advertencia.
    - Requiere la función contar_tokens() y la clase Document definida/importada.
    """
    
    df = pd.read_csv(path_csv).dropna(subset=["corpus"])
    
    # Filtro por año
    if anios:
        if isinstance(anios, int):
            anios = [anios]
        # Convierte a int si tus años están como string
        df = df[df["anno"].isin(anios)]


    if n:
        df = df.head(n)
    print(f"📄 Cargando {len(df)} documentos desde '{path_csv}' (filtrados por año: {anios})...")
    documentos = []
    splitter = None

    if chunk_size and chunk_overlap:
        splitter = RecursiveCharacterTextSplitter(
            chunk_size=chunk_size,
            chunk_overlap=chunk_overlap,
            separators=["\n\n", "\n", ".", " "]
        )

    for _, row in df.iterrows():
        metadatos = {
            "name": row.get("nombre", ""),
            "description": row.get("descripcion", ""),
            "fuente": row.get("fuente", ""),
            "url": row.get("url", ""),
            "tipo_documento": row.get("tipo_documento", ""),
            "relevancia": row.get("relevancia", ""),
            "explicacion": row.get("explicacion", ""),
            "anno": safe_int(row.get("anno", "")),
            "n_tokens": safe_int(contar_tokens(str(row["corpus"]).strip()))
        }
        cuerpo = str(row["corpus"]).strip()
        total_tokens = contar_tokens(cuerpo)

        if total_tokens <= SAFE_TOKENS:
            documentos.append(Document(page_content=cuerpo, metadata=metadatos))
        elif splitter:
            partes = splitter.split_text(cuerpo)
            for parte in partes:
                if contar_tokens(parte) <= SAFE_TOKENS:
                    documentos.append(Document(page_content=parte, metadata=metadatos))
                else:
                    print(f"⚠️ Chunk excede el máximo seguro de tokens, se omitió parcialmente.")
        else:
            print(f"⚠️ Documento omitido por superar límite de tokens y no hay splitter definido.")

    return documentos

def indexar_en_redis(documentos, redis_url, redis_index, gpt_key, eliminar_anteriores=False):
    """
    Indexa una lista de documentos en una base vectorial Redis a través de LangChain.

    - Permite eliminar el índice previo en Redis antes de indexar, si se solicita.
    - Controla el límite de tokens por documento y por lote, omitiendo o fragmentando cuando es necesario.
    - Indexa los documentos en lotes para evitar superar el límite seguro de tokens por operación.
    - Registra los documentos que superan los límites de tokens o generan errores durante la indexación.
    - Guarda un CSV con los errores de indexación, si existen.

    Parámetros:
    - documentos (list): Lista de objetos Document a indexar.
    - redis_url (str): URL de conexión a la base de datos Redis.
    - redis_index (str): Nombre del índice vectorial en Redis.
    - gpt_key (str): API key de OpenAI para embeddings.
    - eliminar_anteriores (bool, opcional): Si True, elimina el índice previo antes de indexar (por defecto False).

    Retorna:
    - int: Número total de documentos efectivamente indexados.

    Notas:
    - Usa la variable SAFE_TOKENS como límite máximo de tokens por documento/lote.
    - Requiere las funciones contar_tokens(), la clase Document, y las clases de embeddings e integración Redis de LangChain.
    - Los errores durante la indexación quedan registrados en 'errores_indexacion.csv'.
    """
    # ... tu código ...

    embeddings = OpenAIEmbeddings(
        model=MODEL_NAME,
        openai_api_key=GPT_KEY
    )

    if eliminar_anteriores:
        print("🧹 Eliminando índice anterior...")
        try:
            r = RedisClient.from_url(redis_url)
            r.ft(redis_index).dropindex(delete_documents=True)
            print(f"🧹 Índice '{redis_index}' eliminado correctamente.")
        except Exception as e:
            print(f"⚠️ No se pudo eliminar el índice '{redis_index}' (puede que no exista): {e}")

    index_schema = {
        "text": [
            {"name": "name"},
            {"name": "description"},
            {"name": "fuente"},
            {"name": "url"},
            {"name": "tipo_documento"},
            {"name": "relevancia"},
            {"name": "explicacion"},
        ],
        "numeric": [
            {"name": "anno"},
            {"name": "n_tokens"},
        

        ],
        "tag": []
    }

    print(f"🚀 Iniciando indexación de {len(documentos)} documentos (con control de tokens)...")

    errores = []
    indexados = []
    lote_actual = []
    tokens_lote = 0

    for i, doc in enumerate(documentos):
        texto = doc.page_content
        tokens_doc = contar_tokens(texto)
        if tokens_doc > SAFE_TOKENS:
            errores.append({
                "indice": i + 1,
                "name": doc.metadata.get('name', f'doc_{i}'),
                "tokens": tokens_doc,
                "error": "Supera SAFE_TOKENS individualmente"
            })
            continue
        if tokens_lote + tokens_doc > SAFE_TOKENS:
            # Indexar lote actual
            RedisVectorStore.from_documents(
                documents=lote_actual,
                embedding=embeddings,
                redis_url=redis_url,
                index_name=redis_index,
                index_schema=index_schema
            )
            indexados.extend(lote_actual)
            print(f"✅ Lote de {len(lote_actual)} documentos indexado.")
            # Resetear lote
            lote_actual = []
            tokens_lote = 0

        lote_actual.append(doc)
        tokens_lote += tokens_doc

    # Indexar último lote si quedó algo pendiente
    if lote_actual:
        try:
            RedisVectorStore.from_documents(
                documents =lote_actual,
                embedding=embeddings,
                redis_url=redis_url,
                index_name=redis_index,
                index_schema=index_schema
            )
            indexados.extend(lote_actual)
            print(f"✅ Último lote de {len(lote_actual)} documentos indexado.")
        except Exception as e:
            print(f"❌ Error en último lote: {str(e)}")
            
            for j, d in enumerate(lote_actual):
                errores.append({
                    "indice": len(indexados) + j + 1,
                    "name": d.metadata.get('name', f'doc_{j}'),
                    "tokens": contar_tokens(d.page_content),
                    "error": f"Error en lote final: {str(e)}"
                })

    print(f"📦 Total indexados: {len(indexados)} / {len(documentos)}")

    if errores:
        df_err = pd.DataFrame(errores)
        df_err.to_csv("errores_indexacion.csv", index=False, encoding="utf-8-sig")
        print("📄 Errores registrados en 'errores_indexacion.csv'")

    return len(indexados)

def buscar_knn_normativas(query: str, k: int = 5, min_score: float = 0.0):
    """
    Realiza una búsqueda KNN (k-Nearest Neighbors) en Redis para encontrar normativas similares a una consulta.

    - Obtiene el embedding de la consulta usando el modelo de OpenAI.
    - Ejecuta la búsqueda vectorial KNN sobre el índice 'normativas_sii' en Redis.
    - Procesa los resultados filtrando por un puntaje mínimo (min_score).
    - Presenta los resultados en una tabla HTML interactiva, donde el nombre enlaza a la URL de la normativa (si está disponible).
    - Devuelve los resultados como un DataFrame de pandas.

    Parámetros:
    - query (str): Consulta de texto a buscar.
    - k (int, opcional): Número de vecinos más cercanos a recuperar (default = 5).
    - min_score (float, opcional): Puntaje mínimo requerido para incluir un resultado (default = 0.0).

    Retorna:
    - pd.DataFrame: DataFrame con los resultados filtrados, incluyendo columnas 'name', 'relevancia', 'explicacion' y 'vector_score'.

    Notas:
    - Requiere variables globales para la conexión Redis: REDIS_HOST, REDIS_PORT, REDIS_DB, REDIS_USERNAME, REDIS_PASSWORD, y GPT_KEY.
    - Utiliza el modelo 'text-embedding-3-large' de OpenAI para embeddings.
    - El enlace en la columna 'name' solo aparece si la URL está disponible.
    - Muestra la tabla en HTML directamente en el notebook.

 
    """
    
    # Obtener embedding
    embeddings = OpenAIEmbeddings(
        model=MODEL_NAME,  # Dimensión fija de 6144
        openai_api_key=GPT_KEY
    )
    query_vector = embeddings.embed_query(query)

    # Conexión Redis
    r = RedisClient.Redis(
        host=REDIS_HOST,
        port=int(REDIS_PORT),
        db=REDIS_DB,
        username=REDIS_USERNAME,
        password=REDIS_PASSWORD,
        decode_responses=True
    )

    # Búsqueda
    base_query = f"*=>[KNN {k} @content_vector $vec as vector_score]"
    q = (
        Query(base_query)
        .return_fields("name", "relevancia", "explicacion", "url", "vector_score")
        .sort_by("vector_score")
        .dialect(2)
    )

    results = r.ft("normativas_sii").search(
        q, query_params={"vec": np.array(query_vector, dtype=np.float32).tobytes()}
    )

    # Procesar resultados
    filas = []
    for doc in results.docs:
        score = float(doc.vector_score)
        if score >= min_score:
            nombre = getattr(doc, "name", "")
            url = getattr(doc, "url", "")
            nombre_link = f'<a href="{url}" target="_blank">{nombre}</a>' if url else nombre

            filas.append({
                "name": nombre_link,
                "relevancia": getattr(doc, "relevancia", ""),
                "explicacion": getattr(doc, "explicacion", ""),
                "vector_score": round(score, 4)
            })

    # Mostrar en HTML
    df = pd.DataFrame(filas)
    display(HTML(df.to_html(escape=False, index=False)))

    return df

def safe_int(val):
    try:
        return int(val)
    except (ValueError, TypeError):
        return None

# %% [markdown]
# ## 4.2 Preprocesar Documentos
# Se estructura la información para su integración en Redis, asignando claves únicas a cada normativa y asociando sus respectivos embeddings. Esta organización es fundamental para facilitar la recuperación rápida y precisa de normativas relevantes mediante consultas vectoriales.

# %%
# Mostrar muestra de documentos cargados
documentos = preparar_documentos(
    path_csv=f"{DATA_DIR}/{CSV_PATH}",
    n=None,
    anios=[2020,2021,2022,2023,2024],
    chunk_size=1000,
    chunk_overlap=200
)
print(f"Total de documentos preparados: {len(documentos)}")
# Out:
# 📄 Cargando 1032 documentos desde '../raw_data/classified_regulations.csv' (filtrados por año: [2020, 2021, 2022, 2023, 2024])...
# Total de documentos preparados: 3039

# %%
resumen_chunks_por_documento(documentos)
# Out:
# Total de chunks generados: 3039
# Resumen por documento:
# - Resolución Exenta SII N° 143 del 23 de Noviembre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 86 del 30 de Julio del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 25 del 04 de Marzo del 2022: 1 chunk(s)
# - Circular N° 28 del 09 de Julio del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 64 del 07 de Junio del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 121 del 19 de Diciembre del 2024: 1 chunk(s)
# - Circular N° 2 del 09 de Enero del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 95 del 31 de Agosto del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 117 del 12 de Diciembre del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 31 del 11 de Abril del 2022: 1 chunk(s)
# - Circular N° 59 del 10 de Septiembre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 03 del 12 de Enero del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 146 del 21 de Diciembre del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 37 del 21 de Marzo del 2023: 1 chunk(s)
# - Circular N° 29 del 13 de Abril del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 148 del 28 de Diciembre del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 128 del 29 de Diciembre del 2022: 1 chunk(s)
# - Circular N° 41 del 12 de Septiembre del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 60 del 17 de Mayo del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 142 del 20 de Noviembre del 2020: 1 chunk(s)
# - Circular N° 32 del 29 de Abril del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 36 del 22 de Abril del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 93 del 30 de Julio del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 83 del 03 de Agosto del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 121 del 16 de Octubre del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 52 del 08 de Mayo del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 116 del 11 de Diciembre del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 27 del 09 de Marzo del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 127 del 11 de Noviembre del 2021: 1 chunk(s)
# - Circular N° 31 del 12 de Julio del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 80 del 30 de Junio del 2023: 1 chunk(s)
# - Circular N° 25 del 08 de Abril del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 133 del 26 de Diciembre del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 58 del 11 de Junio del 2021: 1 chunk(s)
# - Circular N° 46 del 13 de Julio del 2021: 1 chunk(s)
# - Circular N° 1 del 09 de Enero del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 112 del 04 de Octubre del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 176 del 31 de Diciembre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 45 del 06 de Abril del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 86 del 17 de Agosto del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 72 del 01 de Julio del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 52 del 27 de Abril del 2023: 1 chunk(s)
# - Circular N° 15 del 11 de Abril del 2022: 1 chunk(s)
# - Circular N° 34 del 04 de Agosto del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 66 del 08 de Junio del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 70 del 30 de Junio del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 126 del 28 de Diciembre del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 23 del 12 de Febrero del 2020: 1 chunk(s)
# - Circular N° 18 del 13 de Abril del 2022: 1 chunk(s)
# - Circular N° 34 del 04 de Junio del 2021: 1 chunk(s)
# - Circular N° 22 del 09 de Abril del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 04 del 13 de Enero del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 137 del 12 de Diciembre del 2023: 1 chunk(s)
# - Circular N° 8 del 09 de Febrero del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 70 del 31 de Agosto del 2022: 1 chunk(s)
# - Circular N° 13 del 11 de Marzo del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 134 del 16 de Octubre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 139 del 20 de Diciembre del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 41 del 13 de Abril del 2020: 1 chunk(s)
# - Circular N° 2 del 09 de Enero del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 80 del 02 de Septiembre del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 82 del 17 de Julio del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 39 del 02 de Mayo del 2022: 1 chunk(s)
# - Circular N° 36 del 15 de Mayo del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 128 del 26 de Diciembre del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 128 del 13 de Noviembre del 2023: 1 chunk(s)
# - Circular N° 42 del 10 de Octubre del 2024: 1 chunk(s)
# - Circular N° 4 del 11 de Enero del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 109 del 15 de Septiembre del 2021: 1 chunk(s)
# - Circular N° 56 del 13 de Octubre del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 124 del 26 de Diciembre del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 46 del 12 de Abril del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 84 del 23 de Julio del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 63 del 06 de Junio del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 01 del 09 de Enero del 2023: 1 chunk(s)
# - Circular N° 13 del 13 de Marzo del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 106 del 07 de Noviembre del 2024: 1 chunk(s)
# - Circular N° 24 del 08 de Junio del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 76 del 28 de Junio del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 47 del 27 de Abril del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 110 del 11 de Septiembre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 78 del 28 de Junio del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 139 del 13 de Diciembre del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 39 del 09 de Abril del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 40 del 03 de Mayo del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 03 del 12 de Enero del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 29 del 09 de Marzo del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 13 del 24 de Enero del 2020: 1 chunk(s)
# - Circular N° 36 del 09 de Junio del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 85 del 30 de Agosto del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 61 del 17 de Junio del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 54 del 04 de Mayo del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 05 del 26 de Enero del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 92 del 12 de Septiembre del 2024: 1 chunk(s)
# - Circular N° 45 del 07 de Julio del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 171 del 29 de Diciembre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 125 del 02 de Noviembre del 2023: 1 chunk(s)
# - Circular N° 30 del 19 de Mayo del 2021: 1 chunk(s)
# - Circular N° 23 del 19 de Mayo del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 40 del 14 de Abril del 2021: 1 chunk(s)
# - Circular N° 14 del 08 de Abril del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 131 del 15 de Noviembre del 2023: 1 chunk(s)
# - Circular N° 7 del 29 de Enero del 2021: 1 chunk(s)
# - Circular N° 26 del 11 de Junio del 2024: 1 chunk(s)
# - Circular N° 44 del 10 de Octubre del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 116 del 12 de Octubre del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 124 del 25 de Octubre del 2023: 1 chunk(s)
# - Circular N° 51 del 10 de Agosto del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 95 del 06 de Octubre del 2022: 1 chunk(s)
# - Circular N° 64 del 09 de Diciembre del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 61 del 19 de Julio del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 99 del 11 de Octubre del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 98 del 26 de Agosto del 2021: 1 chunk(s)
# - Circular N° 18 del 13 de Abril del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 102 del 08 de Noviembre del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 140 del 30 de Octubre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 97 del 10 de Octubre del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 35 del 26 de Marzo del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 44 del 27 de Abril del 2021: 1 chunk(s)
# - Circular N° 29 del 24 de Junio del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 30 del 18 de Marzo del 2020: 1 chunk(s)
# - Circular N° 5 del 14 de Enero del 2021: 1 chunk(s)
# - Circular N° 10 del 07 de Marzo del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 140 del 13 de Diciembre del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 78 del 31 de Agosto del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 53 del 11 de Mayo del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 140 del 28 de Diciembre del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 03 del 10 de Enero del 2020: 1 chunk(s)
# - Circular N° 51 del 09 de Noviembre del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 126 del 20 de Diciembre del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 97 del 28 de Agosto del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 13 del 24 de Enero del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 174 del 30 de Diciembre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 81 del 17 de Julio del 2020: 1 chunk(s)
# - Circular N° 1 del 09 de Enero del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 27 del 03 de Marzo del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 05 del 16 de Enero del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 56 del 09 de Mayo del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 97 del 19 de Agosto del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 01 del 03 de Enero del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 92 del 31 de Agosto del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 102 del 01 de Septiembre del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 83 del 20 de Julio del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 154 del 11 de Diciembre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 62 del 30 de Mayo del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 17 del 31 de Enero del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 108 del 14 de Septiembre del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 143 del 30 de Diciembre del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 57 del 27 de Mayo del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 19 del 31 de Enero del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 13 del 09 de Febrero del 2023: 1 chunk(s)
# - Circular N° 35 del 01 de Agosto del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 34 del 11 de Marzo del 2024: 1 chunk(s)
# - Circular N° 21 del 09 de Mayo del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 06 del 26 de Enero del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 76 del 30 de Julio del 2024: 1 chunk(s)
# - Circular N° 40 del 13 de Septiembre del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 53 del 09 de Junio del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 19 del 06 de Febrero del 2020: 1 chunk(s)
# - Circular N° 25 del 11 de Junio del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 84 del 09 de Agosto del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 146 del 27 de Noviembre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 168 del 28 de Diciembre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 127 del 23 de Diciembre del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 109 del 08 de Septiembre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 113 del 22 de Septiembre del 2023: 1 chunk(s)
# - Circular N° 24 del 23 de Mayo del 2024: 1 chunk(s)
# - Circular N° 35 del 09 de Junio del 2021: 1 chunk(s)
# - Circular N° 3 del 10 de Enero del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 75 del 28 de Junio del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 123 del 18 de Octubre del 2023: 1 chunk(s)
# - Circular N° 47 del 12 de Octubre del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 120 del 15 de Octubre del 2021: 1 chunk(s)
# - Circular N° 36 del 10 de Agosto del 2022: 1 chunk(s)
# - Circular N° 20 del 10 de Mayo del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 30 del 18 de Marzo del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 55 del 20 de Mayo del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 16 del 17 de Febrero del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 15 del 15 de Febrero del 2021: 1 chunk(s)
# - Circular N° 9 del 12 de Febrero del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 56 del 26 de Mayo del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 68 del 30 de Junio del 2021: 1 chunk(s)
# - Circular N° 61 del 11 de Septiembre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 110 del 25 de Noviembre del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 98 del 28 de Agosto del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 15 del 15 de Febrero del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 41 del 31 de Marzo del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 149 del 30 de Noviembre del 2020: 1 chunk(s)
# - Circular N° 34 del 30 de Julio del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 75 del 02 de Julio del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 34 del 21 de Marzo del 2023: 1 chunk(s)
# - Circular N° 33 del 09 de Agosto del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 106 del 03 de Septiembre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 76 del 08 de Julio del 2020: 1 chunk(s)
# - Circular N° 49 del 18 de Octubre del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 82 del 15 de Julio del 2021: 1 chunk(s)
# - Circular N° 1 del 09 de Enero del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 77 del 31 de Agosto del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 13 del 09 de Febrero del 2021: 1 chunk(s)
# - Circular N° 48 del 10 de Agosto del 2021: 1 chunk(s)
# - Circular N° 11 del 12 de Febrero del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 101 del 31 de Agosto del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 20 del 07 de Febrero del 2020: 1 chunk(s)
# - Circular N° 3 del 12 de Enero del 2021: 1 chunk(s)
# - Circular N° 47 del 10 de Noviembre del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 42 del 21 de Abril del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 115 del 08 de Octubre del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 91 del 23 de Agosto del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 68 del 26 de Junio del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 159 del 15 de Diciembre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 71 del 01 de Julio del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 47 del 15 de Abril del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 101 del 31 de Agosto del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 74 del 19 de Julio del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 102 del 24 de Octubre del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 58 del 29 de Junio del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 46 del 12 de Abril del 2024: 1 chunk(s)
# - Circular N° 31 del 20 de Julio del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 81 del 09 de Julio del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 105 del 30 de Octubre del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 62 del 03 de Junio del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 59 del 12 de Julio del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 14 del 12 de Febrero del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 61 del 24 de Mayo del 2024: 1 chunk(s)
# - Circular N° 2 del 09 de Enero del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 29 del 15 de Marzo del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 114 del 05 de Diciembre del 2024: 1 chunk(s)
# - Circular N° 29 del 10 de Julio del 2023: 1 chunk(s)
# - Circular N° 8 del 09 de Febrero del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 99 del 27 de Agosto del 2021: 1 chunk(s)
# - Circular N° 24 del 13 de Abril del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 90 del 30 de Julio del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 25 del 19 de Febrero del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 126 del 10 de Noviembre del 2021: 1 chunk(s)
# - Circular N° 54 del 20 de Diciembre del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 32 del 07 de Marzo del 2024: 1 chunk(s)
# - Circular N° 1 del 11 de Enero del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 43 del 20 de Abril del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 41 del 06 de Mayo del 2022: 1 chunk(s)
# - Circular N° 40 del 12 de Septiembre del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 50 del 26 de Abril del 2023: 1 chunk(s)
# - Circular N° 37 del 06 de Septiembre del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 118 del 12 de Diciembre del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 125 del 20 de Diciembre del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 12 del 17 de Enero del 2024: 1 chunk(s)
# - Circular N° 58 del 10 de Septiembre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 57 del 28 de Junio del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 111 del 01 de Octubre del 2021: 1 chunk(s)
# - Circular N° 15 del 09 de Abril del 2024: 1 chunk(s)
# - Circular N° 44 del 12 de Julio del 2021: 1 chunk(s)
# - Circular N° 27 del 09 de Abril del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 60 del 14 de Junio del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 113 del 05 de Diciembre del 2024: 1 chunk(s)
# - Circular N° 5 del 12 de Enero del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 48 del 20 de Mayo del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 26 del 14 de Marzo del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 117 del 02 de Diciembre del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 06 del 10 de Enero del 2024: 1 chunk(s)
# - Circular N° 52 del 09 de Noviembre del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 08 del 10 de Enero del 2024: 1 chunk(s)
# - Circular N° 46 del 09 de Julio del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 84 del 30 de Agosto del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 50 del 24 de Abril del 2024: 1 chunk(s)
# - Circular N° 9 del 15 de Febrero del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 120 del 18 de Diciembre del 2024: 1 chunk(s)
# - Circular N° 53 del 19 de Diciembre del 2024: 1 chunk(s)
# - Circular N° 24 del 10 de Mayo del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 15 del 24 de Enero del 2024: 1 chunk(s)
# - Circular N° 7 del 17 de Enero del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 128 del 11 de Noviembre del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 55 del 04 de Mayo del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 61 del 18 de Mayo del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 125 del 08 de Noviembre del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 63 del 24 de Junio del 2020: 1 chunk(s)
# - Circular N° 15 del 11 de Marzo del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 89 del 23 de Agosto del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 107 del 08 de Septiembre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 50 del 04 de Mayo del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 01 del 05 de Enero del 2021: 1 chunk(s)
# - Circular N° 24 del 03 de Abril del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 133 del 05 de Octubre del 2020: 1 chunk(s)
# - Circular N° 31 del 19 de Mayo del 2021: 160 chunk(s)
# - Resolución Exenta SII N° 20 del 31 de Enero del 2024: 1 chunk(s)
# - Circular N° 62 del 24 de Septiembre del 2020: 358 chunk(s)
# - Resolución Exenta SII N° 71 del 31 de Agosto del 2022: 1 chunk(s)
# - Circular N° 17 del 10 de Abril del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 67 del 15 de Junio del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 105 del 03 de Septiembre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 34 del 19 de Abril del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 37 del 15 de Marzo del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 34 del 31 de Marzo del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 73 del 02 de Julio del 2020: 1 chunk(s)
# - Circular N° 1 del 11 de Enero del 2021: 1 chunk(s)
# - Circular N° 54 del 27 de Diciembre del 2024: 1 chunk(s)
# - Circular N° 46 del 11 de Noviembre del 2024: 1 chunk(s)
# - Circular N° 35 del 04 de Agosto del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 22 del 05 de Febrero del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 136 del 20 de Diciembre del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 123 del 21 de Diciembre del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 02 del 07 de Enero del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 106 del 17 de Noviembre del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 81 del 02 de Septiembre del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 115 del 04 de Octubre del 2023: 1 chunk(s)
# - Circular N° 42 del 02 de Julio del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 65 del 06 de Junio del 2023: 1 chunk(s)
# - Circular N° 18 del 01 de Abril del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 27 del 14 de Febrero del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 78 del 05 de Agosto del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 09 del 31 de Enero del 2022: 1 chunk(s)
# - Circular N° 30 del 05 de Julio del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 81 del 29 de Agosto del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 113 del 25 de Noviembre del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 31 del 19 de Marzo del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 76 del 06 de Julio del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 21 del 03 de Marzo del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 55 del 17 de Junio del 2022: 1 chunk(s)
# - Circular N° 14 del 14 de Marzo del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 127 del 13 de Noviembre del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 10 del 22 de Enero del 2020: 1 chunk(s)
# - Circular N° 50 del 31 de Julio del 2020: 1 chunk(s)
# - Circular N° 26 del 09 de Junio del 2022: 1 chunk(s)
# - Circular N° 50 del 29 de Noviembre del 2023: 1 chunk(s)
# - Circular N° 73 del 22 de Diciembre del 2020: 503 chunk(s)
# - Circular N° 43 del 05 de Julio del 2021: 175 chunk(s)
# - Circular N° 26 del 09 de Junio del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 63 del 22 de Julio del 2022: 1 chunk(s)
# - Circular N° 44 del 26 de Junio del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 60 del 12 de Julio del 2022: 1 chunk(s)
# - Circular N° 33 del 11 de Mayo del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 58 del 29 de Mayo del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 96 del 17 de Agosto del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 93 del 12 de Septiembre del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 130 del 30 de Septiembre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 114 del 28 de Noviembre del 2022: 1 chunk(s)
# - Circular N° 33 del 19 de Julio del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 22 del 12 de Febrero del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 173 del 30 de Diciembre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 101 del 01 de Septiembre del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 44 del 11 de Abril del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 30 del 16 de Marzo del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 09 del 27 de Enero del 2023: 1 chunk(s)
# - Circular N° 40 del 25 de Junio del 2021: 1 chunk(s)
# - Circular N° 57 del 13 de Octubre del 2021: 1 chunk(s)
# - Circular N° 43 del 10 de Octubre del 2024: 1 chunk(s)
# - Circular N° 38 del 22 de Agosto del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 32 del 21 de Marzo del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 94 del 31 de Agosto del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 132 del 02 de Octubre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 162 del 17 de Diciembre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 106 del 02 de Septiembre del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 126 del 10 de Noviembre del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 43 del 06 de Abril del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 18 del 06 de Febrero del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 129 del 15 de Noviembre del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 79 del 29 de Junio del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 133 del 30 de Noviembre del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 56 del 09 de Junio del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 40 del 26 de Marzo del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 22 del 03 de Marzo del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 145 del 21 de Diciembre del 2023: 1 chunk(s)
# - Circular N° 10 del 23 de Febrero del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 169 del 29 de Diciembre del 2020: 1 chunk(s)
# - Circular N° 27 del 12 de Junio del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 11 del 04 de Febrero del 2021: 1 chunk(s)
# - Circular N° 58 del 28 de Diciembre del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 28 del 16 de Marzo del 2022: 1 chunk(s)
# - Circular N° 41 del 02 de Julio del 2021: 181 chunk(s)
# - Resolución Exenta SII N° 70 del 20 de Junio del 2023: 1 chunk(s)
# - Circular N° 39 del 11 de Septiembre del 2024: 1 chunk(s)
# - Circular N° 49 del 20 de Julio del 2020: 1 chunk(s)
# - Circular N° 18 del 19 de Marzo del 2020: 1 chunk(s)
# - Circular N° 43 del 14 de Septiembre del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 85 del 22 de Julio del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 51 del 18 de Mayo del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 123 del 30 de Septiembre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 135 del 30 de Diciembre del 2024: 1 chunk(s)
# - Circular N° 57 del 10 de Septiembre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 33 del 24 de Marzo del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 122 del 18 de Octubre del 2023: 1 chunk(s)
# - Circular N° 46 del 12 de Octubre del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 135 del 04 de Diciembre del 2023: 1 chunk(s)
# - Circular N° 52 del 12 de Diciembre del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 77 del 01 de Agosto del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 24 del 28 de Febrero del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 91 del 12 de Septiembre del 2024: 1 chunk(s)
# - Circular N° 38 del 06 de Septiembre del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 32 del 23 de Marzo del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 66 del 02 de Agosto del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 37 del 31 de Marzo del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 110 del 28 de Noviembre del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 122 del 19 de Diciembre del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 31 del 21 de Marzo del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 32 del 23 de Marzo del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 167 del 28 de Diciembre del 2020: 1 chunk(s)
# - Circular N° 17 del 12 de Abril del 2022: 1 chunk(s)
# - Circular N° 4 del 15 de Enero del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 76 del 31 de Agosto del 2022: 1 chunk(s)
# - Circular N° 49 del 10 de Agosto del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 68 del 28 de Junio del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 100 del 31 de Agosto del 2021: 1 chunk(s)
# - Circular N° 21 del 21 de Abril del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 108 del 08 de Septiembre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 17 del 18 de Febrero del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 166 del 23 de Diciembre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 96 del 10 de Octubre del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 46 del 13 de Mayo del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 90 del 23 de Agosto del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 17 del 17 de Febrero del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 91 del 21 de Agosto del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 47 del 13 de Abril del 2023: 1 chunk(s)
# - Circular N° 41 del 13 de Septiembre del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 99 del 28 de Agosto del 2020: 1 chunk(s)
# - Circular N° 39 del 08 de Junio del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 104 del 02 de Septiembre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 19 del 23 de Febrero del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 88 del 22 de Agosto del 2023: 1 chunk(s)
# - Circular N° 10 del 09 de Marzo del 2022: 1 chunk(s)
# - Circular N° 60 del 10 de Noviembre del 2021: 1 chunk(s)
# - Circular N° 25 del 09 de Junio del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 175 del 31 de Diciembre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 28 del 28 de Febrero del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 109 del 14 de Septiembre del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 130 del 26 de Diciembre del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 96 del 25 de Agosto del 2020: 1 chunk(s)
# - Circular N° 32 del 09 de Agosto del 2023: 1 chunk(s)
# - Circular N° 71 del 10 de Diciembre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 87 del 27 de Julio del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 132 del 26 de Noviembre del 2021: 1 chunk(s)
# - Circular N° 38 del 11 de Junio del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 160 del 16 de Diciembre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 147 del 27 de Diciembre del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 34 del 25 de Marzo del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 05 del 10 de Enero del 2024: 1 chunk(s)
# - Circular N° 12 del 17 de Febrero del 2021: 274 chunk(s)
# - Resolución Exenta SII N° 103 del 01 de Septiembre del 2020: 1 chunk(s)
# - Circular N° 16 del 09 de Abril del 2024: 1 chunk(s)
# - Circular N° 45 del 25 de Octubre del 2024: 1 chunk(s)
# - Circular N° 37 del 10 de Agosto del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 53 del 02 de Mayo del 2024: 1 chunk(s)
# - Circular N° 6 del 20 de Enero del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 38 del 18 de Marzo del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 114 del 07 de Octubre del 2021: 1 chunk(s)
# - Circular N° 48 del 10 de Noviembre del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 80 del 28 de Agosto del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 119 del 13 de Octubre del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 57 del 09 de Mayo del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 80 del 14 de Julio del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 11 del 17 de Enero del 2024: 1 chunk(s)
# - Circular N° 21 del 15 de Mayo del 2024: 1 chunk(s)
# - Circular N° 21 del 25 de Marzo del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 100 del 31 de Agosto del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 07 del 25 de Enero del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 90 del 12 de Agosto del 2020: 1 chunk(s)
# - Circular N° 54 del 09 de Diciembre del 2022: 1 chunk(s)
# - Circular N° 60 del 11 de Septiembre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 31 del 07 de Marzo del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 122 del 29 de Octubre del 2021: 1 chunk(s)
# - Circular N° 2 del 11 de Enero del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 03 del 08 de Enero del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 85 del 09 de Agosto del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 39 del 25 de Marzo del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 118 del 07 de Diciembre del 2022: 1 chunk(s)
# - Circular N° 14 del 26 de Febrero del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 63 del 30 de Mayo del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 87 del 22 de Agosto del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 54 del 18 de Mayo del 2020: 1 chunk(s)
# - Circular N° 16 del 11 de Marzo del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 93 del 31 de Agosto del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 141 del 13 de Noviembre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 07 del 17 de Enero del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 109 del 21 de Noviembre del 2022: 1 chunk(s)
# - Circular N° 50 del 13 de Agosto del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 17 del 18 de Febrero del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 107 del 14 de Noviembre del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 150 del 28 de Diciembre del 2023: 1 chunk(s)
# - Circular N° 20 del 09 de Mayo del 2023: 1 chunk(s)
# - Circular N° 42 del 12 de Septiembre del 2022: 1 chunk(s)
# - Circular N° 49 del 13 de Noviembre del 2023: 1 chunk(s)
# - Circular N° 10 del 12 de Febrero del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 135 del 23 de Octubre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 19 del 23 de Febrero del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 79 del 31 de Agosto del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 73 del 22 de Junio del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 47 del 20 de Mayo del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 29 del 11 de Marzo del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 129 del 15 de Noviembre del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 45 del 24 de Abril del 2020: 1 chunk(s)
# - Circular N° 42 del 04 de Octubre del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 16 del 24 de Enero del 2024: 1 chunk(s)
# - Circular N° 22 del 16 de Mayo del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 73 del 05 de Julio del 2024: 1 chunk(s)
# - Circular N° 11 del 09 de Marzo del 2022: 1 chunk(s)
# - Circular N° 36 del 09 de Agosto del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 110 del 20 de Septiembre del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 10 del 27 de Enero del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 15 del 14 de Febrero del 2022: 1 chunk(s)
# - Circular N° 23 del 31 de Marzo del 2020: 1 chunk(s)
# - Circular N° 50 del 28 de Noviembre del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 122 del 29 de Septiembre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 36 del 27 de Marzo del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 131 del 02 de Octubre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 156 del 14 de Diciembre del 2020: 1 chunk(s)
# - Circular N° 55 del 08 de Octubre del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 35 del 21 de Abril del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 65 del 02 de Agosto del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 111 del 25 de Noviembre del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 143 del 15 de Diciembre del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 84 del 08 de Septiembre del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 07 del 22 de Enero del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 66 del 25 de Junio del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 43 del 10 de Mayo del 2022: 1 chunk(s)
# - Circular N° 39 del 13 de Septiembre del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 121 del 21 de Diciembre del 2022: 1 chunk(s)
# - Circular N° 16 del 12 de Abril del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 23 del 26 de Febrero del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 20 del 24 de Febrero del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 67 del 28 de Junio del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 115 del 30 de Noviembre del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 55 del 04 de Junio del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 69 del 28 de Junio del 2024: 1 chunk(s)
# - Circular N° 20 del 21 de Abril del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 05 del 15 de Enero del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 18 del 22 de Febrero del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 97 del 06 de Octubre del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 105 del 01 de Septiembre del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 18 del 22 de Febrero del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 107 del 06 de Septiembre del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 32 del 12 de Abril del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 43 del 03 de Abril del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 10 del 31 de Enero del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 92 del 21 de Agosto del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 116 del 04 de Octubre del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 95 del 25 de Agosto del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 36 del 31 de Marzo del 2021: 1 chunk(s)
# - Circular N° 39 del 31 de Agosto del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 26 del 07 de Marzo del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 49 del 30 de Abril del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 158 del 15 de Diciembre del 2020: 1 chunk(s)
# - Circular N° 41 del 11 de Septiembre del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 91 del 29 de Septiembre del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 118 del 28 de Septiembre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 50 del 10 de Mayo del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 94 del 11 de Agosto del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 104 del 25 de Octubre del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 131 del 19 de Noviembre del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 152 del 09 de Diciembre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 119 del 15 de Octubre del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 57 del 09 de Junio del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 23 del 03 de Marzo del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 75 del 31 de Agosto del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 42 del 06 de Abril del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 90 del 11 de Septiembre del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 103 del 31 de Agosto del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 115 del 05 de Diciembre del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 124 del 05 de Noviembre del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 84 del 22 de Julio del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 128 del 30 de Septiembre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 93 del 24 de Agosto del 2020: 1 chunk(s)
# - Circular N° 44 del 11 de Octubre del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 21 del 05 de Febrero del 2024: 1 chunk(s)
# - Circular N° 11 del 09 de Marzo del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 29 del 24 de Marzo del 2022: 1 chunk(s)
# - Circular N° 28 del 10 de Mayo del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 72 del 22 de Junio del 2023: 1 chunk(s)
# - Circular N° 36 del 31 de Agosto del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 134 del 29 de Noviembre del 2023: 1 chunk(s)
# - Circular N° 4 del 10 de Enero del 2020: 1 chunk(s)
# - Circular N° 5 del 17 de Enero del 2020: 1 chunk(s)
# - Circular N° 15 del 06 de Abril del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 44 del 24 de Abril del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 141 del 13 de Diciembre del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 38 del 27 de Marzo del 2023: 1 chunk(s)
# - Circular N° 55 del 18 de Agosto del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 16 del 05 de Febrero del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 103 del 04 de Septiembre del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 24 del 07 de Febrero del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 35 del 15 de Marzo del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 59 del 01 de Junio del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 38 del 07 de Abril del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 125 del 30 de Septiembre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 20 del 24 de Febrero del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 08 del 17 de Enero del 2020: 1 chunk(s)
# - Circular N° 31 del 11 de Julio del 2022: 1 chunk(s)
# - Circular N° 29 del 11 de Mayo del 2021: 1 chunk(s)
# - Circular N° 17 del 11 de Marzo del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 06 del 17 de Enero del 2020: 1 chunk(s)
# - Circular N° 32 del 19 de Julio del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 107 del 06 de Septiembre del 2023: 1 chunk(s)
# - Circular N° 50 del 27 de Octubre del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 48 del 29 de Abril del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 147 del 27 de Noviembre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 13 del 08 de Febrero del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 18 del 22 de Febrero del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 94 del 04 de Octubre del 2022: 1 chunk(s)
# - Circular N° 23 del 23 de Mayo del 2024: 1 chunk(s)
# - Circular N° 17 del 11 de Marzo del 2020: 1 chunk(s)
# - Circular N° 4 del 18 de Enero del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 08 del 25 de Enero del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 45 del 13 de Mayo del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 10 del 17 de Enero del 2024: 1 chunk(s)
# - Circular N° 66 del 16 de Diciembre del 2021: 1 chunk(s)
# - Circular N° 20 del 25 de Marzo del 2020: 1 chunk(s)
# - Circular N° 53 del 11 de Noviembre del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 142 del 30 de Diciembre del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 11 del 02 de Febrero del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 95 del 13 de Agosto del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 135 del 10 de Diciembre del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 64 del 31 de Mayo del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 55 del 07 de Mayo del 2024: 1 chunk(s)
# - Circular N° 37 del 11 de Junio del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 88 del 27 de Julio del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 83 del 07 de Septiembre del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 98 del 18 de Octubre del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 52 del 24 de Abril del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 114 del 22 de Septiembre del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 04 del 10 de Enero del 2024: 1 chunk(s)
# - Circular N° 51 del 10 de Septiembre del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 52 del 25 de Mayo del 2021: 1 chunk(s)
# - Circular N° 52 del 09 de Diciembre del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 16 del 16 de Febrero del 2023: 1 chunk(s)
# - Circular N° 17 del 09 de Abril del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 44 del 12 de Mayo del 2022: 1 chunk(s)
# - Circular N° 32 del 11 de Julio del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 136 del 23 de Octubre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 45 del 29 de Abril del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 129 del 26 de Diciembre del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 133 del 23 de Noviembre del 2023: 1 chunk(s)
# - Circular N° 68 del 11 de Noviembre del 2020: 1 chunk(s)
# - Circular N° 53 del 10 de Septiembre del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 05 del 17 de Enero del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 78 del 09 de Julio del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 138 del 20 de Diciembre del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 04 del 10 de Enero del 2020: 1 chunk(s)
# - Circular N° 22 del 10 de Mayo del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 36 del 15 de Marzo del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 136 del 12 de Diciembre del 2023: 1 chunk(s)
# - Circular N° 16 del 10 de Abril del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 87 del 30 de Agosto del 2024: 1 chunk(s)
# - Circular N° 51 del 04 de Diciembre del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 09 del 20 de Enero del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 68 del 15 de Junio del 2023: 1 chunk(s)
# - Circular N° 65 del 13 de Octubre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 14 del 24 de Enero del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 121 del 26 de Octubre del 2021: 1 chunk(s)
# - Circular N° 6 del 17 de Enero del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 88 del 02 de Septiembre del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 27 del 28 de Febrero del 2020: 1 chunk(s)
# - Circular N° 12 del 17 de Marzo del 2022: 1 chunk(s)
# - Circular N° 8 del 10 de Febrero del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 125 del 26 de Diciembre del 2022: 1 chunk(s)
# - Circular N° 53 del 10 de Agosto del 2020: 234 chunk(s)
# - Resolución Exenta SII N° 62 del 24 de Junio del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 108 del 10 de Septiembre del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 71 del 22 de Junio del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 24 del 08 de Marzo del 2023: 1 chunk(s)
# - Circular N° 28 del 09 de Abril del 2020: 1 chunk(s)
# - Circular N° 69 del 12 de Noviembre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 27 del 14 de Marzo del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 75 del 03 de Julio del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 127 del 30 de Septiembre del 2020: 1 chunk(s)
# - Circular N° 35 del 16 de Agosto del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 132 del 20 de Noviembre del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 79 del 23 de Agosto del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 109 del 28 de Noviembre del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 144 del 31 de Diciembre del 2021: 1 chunk(s)
# - Circular N° 26 del 09 de Abril del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 61 del 14 de Junio del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 03 del 11 de Enero del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 153 del 10 de Diciembre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 72 del 31 de Agosto del 2022: 1 chunk(s)
# - Circular N° 45 del 12 de Julio del 2021: 1 chunk(s)
# - Circular N° 47 del 03 de Agosto del 2021: 1 chunk(s)
# - Circular N° 47 del 09 de Julio del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 138 del 13 de Diciembre del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 51 del 24 de Abril del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 104 del 31 de Agosto del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 111 del 14 de Septiembre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 09 del 10 de Enero del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 87 del 14 de Septiembre del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 04 del 18 de Enero del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 33 del 11 de Marzo del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 07 del 28 de Enero del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 63 del 23 de Junio del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 105 del 06 de Septiembre del 2023: 1 chunk(s)
# - Circular N° 27 del 10 de Mayo del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 29 del 26 de Febrero del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 94 del 24 de Agosto del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 07 del 10 de Enero del 2024: 1 chunk(s)
# - Circular N° 11 del 17 de Febrero del 2021: 1 chunk(s)
# - Circular N° 62 del 23 de Noviembre del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 124 del 19 de Diciembre del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 42 del 20 de Abril del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 54 del 01 de Junio del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 51 del 26 de Abril del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 117 del 28 de Septiembre del 2020: 1 chunk(s)
# - Circular N° 5 del 17 de Enero del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 01 del 02 de Enero del 2020: 1 chunk(s)
# - Circular N° 65 del 09 de Diciembre del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 22 del 25 de Febrero del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 130 del 15 de Noviembre del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 98 del 31 de Agosto del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 53 del 04 de Mayo del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 115 del 23 de Septiembre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 89 del 15 de Septiembre del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 08 del 27 de Enero del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 170 del 29 de Diciembre del 2020: 1 chunk(s)
# - Circular N° 63 del 13 de Octubre del 2020: 1 chunk(s)
# - Circular N° 56 del 14 de Diciembre del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 06 del 15 de Enero del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 45 del 11 de Abril del 2024: 1 chunk(s)
# - Circular N° 6 del 09 de Febrero del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 37 del 02 de Abril del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 82 del 29 de Agosto del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 112 del 28 de Noviembre del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 130 del 15 de Noviembre del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 30 del 05 de Marzo del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 28 del 05 de Marzo del 2021: 1 chunk(s)
# - Circular N° 21 del 08 de Abril del 2021: 1 chunk(s)
# - Circular N° 13 del 18 de Marzo del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 65 del 25 de Junio del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 33 del 21 de Marzo del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 42 del 06 de Mayo del 2022: 1 chunk(s)
# - Circular N° 54 del 30 de Septiembre del 2021: 1 chunk(s)
# - Circular N° 3 del 13 de Enero del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 117 del 14 de Octubre del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 51 del 31 de Mayo del 2022: 1 chunk(s)
# - Circular N° 54 del 13 de Agosto del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 62 del 22 de Julio del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 129 del 29 de Diciembre del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 149 del 28 de Diciembre del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 49 del 24 de Abril del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 134 del 01 de Diciembre del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 86 del 12 de Septiembre del 2022: 1 chunk(s)
# - Circular N° 33 del 26 de Julio del 2024: 1 chunk(s)
# - Circular N° 8 del 10 de Febrero del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 95 del 10 de Octubre del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 24 del 14 de Febrero del 2020: 1 chunk(s)
# - Circular N° 33 del 25 de Mayo del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 101 del 27 de Octubre del 2022: 1 chunk(s)
# ...
# - Resolución Exenta SII N° 54 del 02 de Mayo del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 24 del 26 de Febrero del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 118 del 15 de Octubre del 2021: 1 chunk(s)
# - Circular N° 18 del 30 de Abril del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 58 del 16 de Mayo del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 104 del 15 de Noviembre del 2022: 1 chunk(s)
# - Circular N° 19 del 10 de Mayo del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 157 del 15 de Diciembre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 129 del 30 de Septiembre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 04 del 16 de Enero del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 108 del 21 de Noviembre del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 123 del 02 de Noviembre del 2021: 1 chunk(s)
# - Circular N° 38 del 09 de Agosto del 2024: 1 chunk(s)
# - Circular N° 40 del 08 de Junio del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 38 del 03 de Abril del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 26 del 03 de Marzo del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 60 del 23 de Mayo del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 66 del 19 de Junio del 2024: 1 chunk(s)
# - Circular N° 30 del 12 de Julio del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 68 del 17 de Agosto del 2022: 1 chunk(s)
# - Circular N° 11 del 11 de Marzo del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 119 del 07 de Diciembre del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 64 del 24 de Junio del 2020: 1 chunk(s)
# - Circular N° 22 del 06 de Mayo del 2022: 1 chunk(s)
# - Circular N° 19 del 19 de Abril del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 70 del 03 de Julio del 2024: 1 chunk(s)
# - Circular N° 25 del 21 de Abril del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 19 del 22 de Febrero del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 103 del 25 de Octubre del 2024: 1 chunk(s)
# - Circular N° 40 del 11 de Septiembre del 2024: 1 chunk(s)
# - Circular N° 58 del 14 de Octubre del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 21 del 24 de Febrero del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 88 del 03 de Agosto del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 119 del 28 de Septiembre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 31 del 18 de Marzo del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 67 del 10 de Agosto del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 38 del 27 de Abril del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 86 del 23 de Julio del 2021: 1 chunk(s)
# - Circular N° 30 del 10 de Julio del 2024: 1 chunk(s)
# - Circular N° 43 del 11 de Octubre del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 02 del 10 de Enero del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 53 del 25 de Mayo del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 137 del 28 de Octubre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 66 del 29 de Junio del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 105 del 16 de Noviembre del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 33 del 19 de Abril del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 71 del 04 de Julio del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 134 del 30 de Diciembre del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 28 del 15 de Marzo del 2023: 1 chunk(s)
# - Circular N° 28 del 10 de Julio del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 100 del 16 de Octubre del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 20 del 23 de Febrero del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 112 del 14 de Septiembre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 33 del 31 de Marzo del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 74 del 02 de Julio del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 106 del 06 de Septiembre del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 74 del 31 de Agosto del 2022: 1 chunk(s)
# - Circular N° 28 del 16 de Junio del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 91 del 30 de Julio del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 69 del 30 de Junio del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 102 del 31 de Agosto del 2021: 1 chunk(s)
# - Circular N° 59 del 22 de Octubre del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 12 del 08 de Febrero del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 57 del 16 de Mayo del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 48 del 17 de Abril del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 62 del 22 de Junio del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 124 del 30 de Septiembre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 123 del 19 de Diciembre del 2024: 1 chunk(s)
# - Circular N° 46 del 13 de Octubre del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 111 del 28 de Noviembre del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 75 del 19 de Julio del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 67 del 26 de Junio del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 23 del 07 de Febrero del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 99 del 26 de Octubre del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 70 del 01 de Julio del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 116 del 23 de Septiembre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 48 del 15 de Abril del 2024: 1 chunk(s)
# - Circular N° 53 del 12 de Diciembre del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 25 del 01 de Marzo del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 80 del 09 de Julio del 2021: 1 chunk(s)
# - Circular N° 15 del 10 de Marzo del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 79 del 08 de Julio del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 49 del 31 de Mayo del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 120 del 13 de Octubre del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 93 del 04 de Octubre del 2022: 1 chunk(s)
# - Circular N° 63 del 25 de Noviembre del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 30 del 25 de Marzo del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 59 del 20 de Mayo del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 111 del 20 de Septiembre del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 77 del 08 de Julio del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 41 del 16 de Abril del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 163 del 18 de Diciembre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 48 del 07 de Mayo del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 43 del 21 de Abril del 2021: 1 chunk(s)
# - Circular N° 41 del 11 de Junio del 2020: 1 chunk(s)
# - Circular N° 2 del 12 de Enero del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 82 del 07 de Septiembre del 2022: 1 chunk(s)
# - Circular N° 7 del 09 de Febrero del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 148 del 27 de Noviembre del 2020: 1 chunk(s)
# - Circular N° 70 del 10 de Diciembre del 2020: 1 chunk(s)
# - Circular N° 37 del 09 de Agosto del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 67 del 30 de Junio del 2021: 1 chunk(s)
# - Circular N° 20 del 01 de Abril del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 12 del 08 de Febrero del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 40 del 31 de Marzo del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 131 del 26 de Diciembre del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 21 del 24 de Febrero del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 102 del 31 de Agosto del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 69 del 30 de Junio del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 74 del 02 de Julio del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 35 del 21 de Marzo del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 02 del 04 de Enero del 2024: 1 chunk(s)
# - Circular N° 61 del 10 de Noviembre del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 25 del 09 de Marzo del 2023: 1 chunk(s)
# - Circular N° 48 del 14 de Noviembre del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 02 del 10 de Enero del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 25 del 07 de Febrero del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 14 del 28 de Enero del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 89 del 05 de Septiembre del 2024: 1 chunk(s)
# - Circular N° 5 del 19 de Enero del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 44 del 06 de Abril del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 41 del 28 de Marzo del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 122 del 21 de Diciembre del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 137 del 20 de Diciembre del 2021: 1 chunk(s)
# - Circular N° 35 del 15 de Mayo del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 79 del 14 de Julio del 2020: 1 chunk(s)
# - Circular N° 16 del 10 de Marzo del 2020: 1 chunk(s)
# - Circular N° 47 del 11 de Noviembre del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 14 del 10 de Febrero del 2022: 1 chunk(s)
# - Circular N° 25 del 13 de Mayo del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 89 del 30 de Julio del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 71 del 30 de Junio del 2020: 1 chunk(s)
# - Circular N° 56 del 04 de Septiembre del 2020: 130 chunk(s)
# - Resolución Exenta SII N° 06 del 23 de Enero del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 47 del 07 de Mayo del 2021: 1 chunk(s)
# - Circular N° 67 del 11 de Noviembre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 73 del 01 de Julio del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 51 del 07 de Mayo del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 101 del 24 de Octubre del 2024: 1 chunk(s)
# - Circular N° 34 del 11 de Agosto del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 23 del 25 de Febrero del 2022: 1 chunk(s)
# - Circular N° 48 del 12 de Octubre del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 37 del 22 de Abril del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 50 del 31 de Mayo del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 59 del 11 de Junio del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 112 del 25 de Noviembre del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 120 del 14 de Diciembre del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 96 del 31 de Agosto del 2023: 1 chunk(s)
# - Circular N° 52 del 10 de Septiembre del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 60 del 09 de Junio del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 64 del 28 de Julio del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 155 del 14 de Diciembre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 11 del 01 de Febrero del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 58 del 16 de Mayo del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 108 del 21 de Noviembre del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 54 del 13 de Junio del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 36 del 21 de Marzo del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 88 del 15 de Septiembre del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 49 del 18 de Abril del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 01 del 04 de Enero del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 151 del 09 de Diciembre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 150 del 02 de Diciembre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 100 del 28 de Agosto del 2020: 1 chunk(s)
# - Circular N° 48 del 14 de Julio del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 98 del 10 de Octubre del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 56 del 24 de Junio del 2022: 1 chunk(s)
# - Circular N° 34 del 11 de Mayo del 2020: 1 chunk(s)
# - Circular N° 29 del 09 de Julio del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 81 del 20 de Julio del 2023: 1 chunk(s)
# - Circular N° 42 del 11 de Junio del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 104 del 06 de Septiembre del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 87 del 30 de Julio del 2020: 1 chunk(s)
# - Circular N° 9 del 10 de Febrero del 2021: 1 chunk(s)
# - Circular N° 57 del 26 de Diciembre del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 39 del 30 de Marzo del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 83 del 29 de Agosto del 2024: 1 chunk(s)
# - Circular N° 6 del 05 de Febrero del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 14 del 10 de Febrero del 2023: 1 chunk(s)
# - Circular N° 31 del 24 de Abril del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 126 del 30 de Septiembre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 26 del 28 de Febrero del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 59 del 17 de Mayo del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 114 del 16 de Septiembre del 2020: 1 chunk(s)
# - Circular N° 66 del 28 de Octubre del 2020: 1 chunk(s)
# - Circular N° 64 del 13 de Octubre del 2020: 1 chunk(s)
# - Circular N° 3 del 09 de Enero del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 46 del 03 de Mayo del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 172 del 30 de Diciembre del 2020: 1 chunk(s)
# - Circular N° 43 del 24 de Junio del 2020: 1 chunk(s)
# - Circular N° 27 del 11 de Junio del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 92 del 29 de Septiembre del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 15 del 04 de Febrero del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 139 del 29 de Octubre del 2020: 1 chunk(s)
# - Circular N° 9 del 21 de Febrero del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 42 del 02 de Abril del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 16 del 15 de Febrero del 2021: 1 chunk(s)
# - Circular N° 14 del 27 de Marzo del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 119 del 12 de Diciembre del 2024: 1 chunk(s)
# - Circular N° 9 del 10 de Febrero del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 99 del 31 de Agosto del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 10 del 29 de Enero del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 69 del 16 de Junio del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 113 del 15 de Septiembre del 2020: 1 chunk(s)
# - Circular N° 72 del 11 de Diciembre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 90 del 22 de Septiembre del 2022: 1 chunk(s)
# - Circular N° 44 del 12 de Octubre del 2022: 1 chunk(s)
# - Circular N° 37 del 20 de Mayo del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 46 del 27 de Abril del 2020: 1 chunk(s)
# - Circular N° 13 del 24 de Febrero del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 77 del 28 de Junio del 2023: 1 chunk(s)
# - Circular N° 14 del 03 de Marzo del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 21 del 11 de Febrero del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 73 del 31 de Agosto del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 116 del 02 de Diciembre del 2022: 1 chunk(s)
# - Circular N° 7 del 09 de Febrero del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 12 del 24 de Enero del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 142 del 13 de Diciembre del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 165 del 22 de Diciembre del 2020: 1 chunk(s)
# - Circular N° 39 del 25 de Junio del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 85 del 23 de Julio del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 52 del 03 de Junio del 2022: 1 chunk(s)
# - Circular N° 22 del 30 de Marzo del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 65 del 29 de Junio del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 121 del 29 de Septiembre del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 72 del 04 de Julio del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 26 del 12 de Febrero del 2024: 1 chunk(s)
# - Circular N° 7 del 09 de Febrero del 2022: 1 chunk(s)
# - Circular N° 26 del 21 de Abril del 2021: 1 chunk(s)
# - Circular N° 52 del 10 de Agosto del 2020: 1 chunk(s)
# - Circular N° 51 del 09 de Diciembre del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 144 del 15 de Diciembre del 2023: 1 chunk(s)
# - Circular N° 19 del 25 de Marzo del 2020: 1 chunk(s)
# - Circular N° 12 del 11 de Marzo del 2024: 1 chunk(s)
# - Circular N° 23 del 10 de Mayo del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 100 del 27 de Octubre del 2022: 1 chunk(s)
# - Resolución Exenta SII N° 40 del 13 de Abril del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 89 del 05 de Agosto del 2020: 1 chunk(s)
# - Resolución Exenta SII N° 110 del 14 de Septiembre del 2023: 1 chunk(s)
# - Circular N° 23 del 09 de Abril del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 94 del 10 de Octubre del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 113 del 05 de Octubre del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 141 del 30 de Diciembre del 2021: 1 chunk(s)
# - Resolución Exenta SII N° 65 del 19 de Junio del 2024: 1 chunk(s)
# - Resolución Exenta SII N° 86 del 30 de Agosto del 2024: 1 chunk(s)
# - Circular N° 3 del 09 de Enero del 2023: 1 chunk(s)
# - Resolución Exenta SII N° 164 del 21 de Diciembre del 2020: 1 chunk(s)

# %% [markdown]
# # 4.3 Preparación para indexación en Redis
# Se estructura la información para su integración en Redis, asignando claves únicas a cada normativa y asociando sus respectivos embeddings. Esta organización es fundamental para facilitar la recuperación rápida y precisa de normativas relevantes mediante consultas vectoriales.
#
# Se realiza la conexión con la instancia de Redis y se procede a la carga de los embeddings generados junto con la metadata correspondiente. Este paso habilita la infraestructura para consultas semánticas, permitiendo la búsqueda y recomendación de normativas en función de la similitud entre textos.

# %%
indexar_en_redis(documentos, REDIS_URL, REDIS_INDEX, GPT_KEY, eliminar_anteriores=True)
# Out:
# 🧹 Eliminando índice anterior...
# ⚠️ No se pudo eliminar el índice 'normativas_sii' (puede que no exista): normativas_sii: no such index
# 🚀 Iniciando indexación de 3039 documentos (con control de tokens)...
# ✅ Lote de 11 documentos indexado.
# ✅ Lote de 9 documentos indexado.
# ✅ Lote de 12 documentos indexado.
# ✅ Lote de 10 documentos indexado.
# ✅ Lote de 7 documentos indexado.
# ✅ Lote de 10 documentos indexado.
# ✅ Lote de 9 documentos indexado.
# ✅ Lote de 16 documentos indexado.
# ✅ Lote de 12 documentos indexado.
# ✅ Lote de 10 documentos indexado.
# ✅ Lote de 16 documentos indexado.
# ✅ Lote de 10 documentos indexado.
# ✅ Lote de 13 documentos indexado.
# ✅ Lote de 16 documentos indexado.
# ✅ Lote de 6 documentos indexado.
# ✅ Lote de 4 documentos indexado.
# ✅ Lote de 9 documentos indexado.
# ✅ Lote de 4 documentos indexado.
# ✅ Lote de 9 documentos indexado.
# ✅ Lote de 2 documentos indexado.
# ✅ Lote de 13 documentos indexado.
# ✅ Lote de 11 documentos indexado.
# ✅ Lote de 11 documentos indexado.
# ✅ Lote de 16 documentos indexado.
# ✅ Lote de 12 documentos indexado.
# ✅ Lote de 7 documentos indexado.
# ✅ Lote de 1 documentos indexado.
# ✅ Lote de 8 documentos indexado.
# ✅ Lote de 25 documentos indexado.
# ✅ Lote de 100 documentos indexado.
# ✅ Lote de 96 documentos indexado.
# ✅ Lote de 99 documentos indexado.
# ✅ Lote de 101 documentos indexado.
# ✅ Lote de 96 documentos indexado.
# ✅ Lote de 19 documentos indexado.
# ✅ Lote de 7 documentos indexado.
# ✅ Lote de 6 documentos indexado.
# ✅ Lote de 28 documentos indexado.
# ✅ Lote de 98 documentos indexado.
# ✅ Lote de 96 documentos indexado.
# ✅ Lote de 99 documentos indexado.
# ✅ Lote de 98 documentos indexado.
# ✅ Lote de 101 documentos indexado.
# ✅ Lote de 98 documentos indexado.
# ✅ Lote de 77 documentos indexado.
# ✅ Lote de 5 documentos indexado.
# ✅ Lote de 10 documentos indexado.
# ✅ Lote de 6 documentos indexado.
# ✅ Lote de 14 documentos indexado.
# ✅ Lote de 78 documentos indexado.
# ✅ Lote de 108 documentos indexado.
# ✅ Lote de 5 documentos indexado.
# ✅ Lote de 12 documentos indexado.
# ✅ Lote de 12 documentos indexado.
# ✅ Lote de 11 documentos indexado.
# ✅ Lote de 9 documentos indexado.
# ✅ Lote de 12 documentos indexado.
# ✅ Lote de 58 documentos indexado.
# ✅ Lote de 107 documentos indexado.
# ✅ Lote de 104 documentos indexado.
# ✅ Lote de 24 documentos indexado.
# ✅ Lote de 6 documentos indexado.
# ✅ Lote de 13 documentos indexado.
# ✅ Lote de 14 documentos indexado.
# ✅ Lote de 9 documentos indexado.
# ✅ Lote de 10 documentos indexado.
# ✅ Lote de 5 documentos indexado.
# ✅ Lote de 7 documentos indexado.
# ✅ Lote de 8 documentos indexado.
# ✅ Lote de 6 documentos indexado.
# ✅ Lote de 8 documentos indexado.
# ✅ Lote de 3 documentos indexado.
# ✅ Lote de 10 documentos indexado.
# ✅ Lote de 13 documentos indexado.
# ✅ Lote de 12 documentos indexado.
# ✅ Lote de 9 documentos indexado.
# ✅ Lote de 15 documentos indexado.
# ✅ Lote de 10 documentos indexado.
# ✅ Lote de 10 documentos indexado.
# ✅ Lote de 14 documentos indexado.
# ✅ Lote de 8 documentos indexado.
# ✅ Lote de 23 documentos indexado.
# ✅ Lote de 105 documentos indexado.
# ✅ Lote de 104 documentos indexado.
# ✅ Lote de 20 documentos indexado.
# ✅ Lote de 9 documentos indexado.
# ✅ Lote de 12 documentos indexado.
# ✅ Lote de 10 documentos indexado.
# ✅ Lote de 8 documentos indexado.
# ✅ Lote de 7 documentos indexado.
# ✅ Lote de 11 documentos indexado.
# ✅ Lote de 8 documentos indexado.
# ✅ Lote de 13 documentos indexado.
# ✅ Lote de 9 documentos indexado.
# ✅ Lote de 14 documentos indexado.
# ✅ Lote de 6 documentos indexado.
# ✅ Lote de 12 documentos indexado.
# ✅ Lote de 10 documentos indexado.
# ✅ Lote de 11 documentos indexado.
# ✅ Lote de 12 documentos indexado.
# ✅ Lote de 8 documentos indexado.
# ✅ Lote de 10 documentos indexado.
# ✅ Lote de 9 documentos indexado.
# ✅ Lote de 5 documentos indexado.
# ✅ Lote de 2 documentos indexado.
# ✅ Lote de 14 documentos indexado.
# ✅ Lote de 7 documentos indexado.
# ✅ Lote de 10 documentos indexado.
# ✅ Lote de 15 documentos indexado.
# ✅ Lote de 11 documentos indexado.
# ✅ Lote de 10 documentos indexado.
# ✅ Lote de 68 documentos indexado.
# ✅ Lote de 72 documentos indexado.
# ✅ Lote de 14 documentos indexado.
# ✅ Lote de 8 documentos indexado.
# ✅ Lote de 7 documentos indexado.
# ✅ Lote de 5 documentos indexado.
# ✅ Lote de 7 documentos indexado.
# ✅ Lote de 6 documentos indexado.
# ✅ Lote de 6 documentos indexado.
# ✅ Lote de 9 documentos indexado.
# ✅ Lote de 9 documentos indexado.
# ✅ Lote de 14 documentos indexado.
# ✅ Lote de 7 documentos indexado.
# ✅ Lote de 3 documentos indexado.
# ✅ Lote de 9 documentos indexado.
# ✅ Último lote de 7 documentos indexado.
# 📦 Total indexados: 3039 / 3039
# 3039

# %% [markdown]
# ## 4.4 Validación del proceso
# Se efectúan pruebas de validación sobre la carga y consulta de embeddings en Redis para asegurar la correcta integración del flujo. Se verifican tanto la recuperación de los vectores como la consistencia de la metadata asociada a cada normativa.

# %%
df = buscar_knn_normativas("¿Qué normativas regulan las boletas electrónicas?", k=5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>name</th>
#       <th>relevancia</th>
#       <th>explicacion</th>
#       <th>vector_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td><a href="https://www.sii.cl/normativa_legislacion/resoluciones/2020/reso108.pdf" target="_blank">Resolución Exenta SII N° 108 del 08 de Septiembre del 2020</a></td>
#       <td>Relevante</td>
#       <td>Clave encontrada: Contiene 'boleta' | Clave encontrada: Contiene 'puntos de venta' | Clave encontrada: Contiene 'operadores'</td>
#       <td>0.3554</td>
#     </tr>
#     <tr>
#       <td><a href="https://www.sii.cl/normativa_legislacion/resoluciones/2022/reso53.pdf" target="_blank">Resolución Exenta SII N° 53 del 09 de Junio del 2022</a></td>
#       <td>Relevante</td>
#       <td>Clave encontrada: Contiene 'cumplimiento tributario'</td>
#       <td>0.3595</td>
#     </tr>
#     <tr>
#       <td><a href="https://www.sii.cl/normativa_legislacion/resoluciones/2020/reso104.pdf" target="_blank">Resolución Exenta SII N° 104 del 02 de Septiembre del 2020</a></td>
#       <td>Relevante</td>
#       <td>Clave encontrada: Contiene 'boleta'</td>
#       <td>0.3648</td>
#     </tr>
#     <tr>
#       <td><a href="https://www.sii.cl/normativa_legislacion/resoluciones/2020/reso152.pdf" target="_blank">Resolución Exenta SII N° 152 del 09 de Diciembre del 2020</a></td>
#       <td>Relevante</td>
#       <td>Clave encontrada: Contiene 'boleta'</td>
#       <td>0.3715</td>
#     </tr>
#     <tr>
#       <td><a href="https://www.sii.cl/normativa_legislacion/resoluciones/2020/reso163.pdf" target="_blank">Resolución Exenta SII N° 163 del 18 de Diciembre del 2020</a></td>
#       <td>Relevante</td>
#       <td>Clave encontrada: Contiene 'boleta' | Clave encontrada: Contiene 'cumplimiento tributario'</td>
#       <td>0.3736</td>
#     </tr>
#   </tbody>
# </table>

# %%
df = buscar_knn_normativas("Encontrar medios de pago", k=5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>name</th>
#       <th>relevancia</th>
#       <th>explicacion</th>
#       <th>vector_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td><a href="https://www.sii.cl/normativa_legislacion/resoluciones/2023/reso106.pdf" target="_blank">Resolución Exenta SII N° 106 del 06 de Septiembre del 2023</a></td>
#       <td>Relevante</td>
#       <td>Clave encontrada: Contiene 'medio de pago' | Clave encontrada: Contiene 'cumplimiento tributario' | Clave encontrada: Contiene 'POS' | Clave encontrada: Contiene 'no presencial' | Clave encontrada: Contiene 'pagos electrónicos'</td>
#       <td>0.6062</td>
#     </tr>
#     <tr>
#       <td><a href="https://www.sii.cl/normativa_legislacion/resoluciones/2020/reso91.pdf" target="_blank">Resolución Exenta SII N° 91 del 21 de Agosto del 2020</a></td>
#       <td>Relevante</td>
#       <td>Clave encontrada: Contiene 'POS'</td>
#       <td>0.6222</td>
#     </tr>
#     <tr>
#       <td><a href="https://www.sii.cl/normativa_legislacion/resoluciones/2020/reso167.pdf" target="_blank">Resolución Exenta SII N° 167 del 28 de Diciembre del 2020</a></td>
#       <td>Relevante</td>
#       <td>Clave encontrada: Contiene 'POS'</td>
#       <td>0.6248</td>
#     </tr>
#     <tr>
#       <td><a href="https://www.sii.cl/normativa_legislacion/resoluciones/2021/reso76.pdf" target="_blank">Resolución Exenta SII N° 76 del 06 de Julio del 2021</a></td>
#       <td>Relevante</td>
#       <td>Clave encontrada: Contiene 'boleta' | Clave encontrada: Contiene 'medio de pago' | Clave encontrada: Contiene 'medios de pago electrónicos' | Clave encontrada: Contiene 'operadores' | Clave encontrada: Contiene 'psp' | Clave encontrada: Contiene 'proveedores de servicios para procesamiento de pagos' | Clave encontrada: Contiene 'no presencial' | Clave encontrada: Contiene 'pagos electrónicos'</td>
#       <td>0.6466</td>
#     </tr>
#     <tr>
#       <td><a href="https://www.sii.cl/normativa_legislacion/resoluciones/2020/reso176.pdf" target="_blank">Resolución Exenta SII N° 176 del 31 de Diciembre del 2020</a></td>
#       <td>Relevante</td>
#       <td>Clave encontrada: Contiene 'boleta' | Clave encontrada: Contiene 'medio de pago' | Clave encontrada: Contiene 'medios de pago electrónicos' | Clave encontrada: Contiene 'POS' | Clave encontrada: Contiene 'pagos electrónicos'</td>
#       <td>0.6490</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 4.5 Conclusiones
#
# En esta etapa se desarrolló el preprocesamiento y la preparación de los textos normativos para la generación de embeddings vectoriales, con el propósito de habilitar la indexación y recuperación semántica eficiente en una base de datos Redis. El flujo de trabajo implementado incluyó la carga de datos preprocesados, la normalización y depuración adicional de los textos, y la obtención de representaciones vectoriales mediante modelos de lenguaje avanzados.
#
# Posteriormente, los documentos y sus embeddings fueron organizados y estructurados para su integración en Redis, asignando claves únicas y asociando la metadata relevante. Se estableció un pipeline robusto para la indexación, que contempla la gestión de límites de tokens, la fragmentación inteligente de textos largos (chunking), y el control de errores en la carga masiva, asegurando la integridad y trazabilidad de los datos.
#
# Este proceso permite habilitar funcionalidades de búsqueda y recuperación semántica avanzada, donde consultas en lenguaje natural pueden ser eficientemente mapeadas y comparadas contra el corpus normativo. La infraestructura construida, basada en Redis y modelos de embeddings de última generación, sienta las bases para el desarrollo de sistemas de recomendación, análisis automatizado y consulta inteligente de normativas legales, contribuyendo a la modernización y eficiencia en la gestión documental y normativa.
#
# La metodología implementada garantiza la reproducibilidad, escalabilidad y calidad del sistema, posicionando la solución para aplicaciones futuras en análisis jurídico, cumplimiento normativo asistido por IA y automatización avanzada de flujos legales.
